# %% [markdown]
# - real life datasets can be large or small
# - image pipeline are a efficient way to handle large dataset
# - data augumentation is a technique of augumenting data, which act as regularizer and hence reduces overfitting

# %%
import numpy as np
import keras
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
image_gen=ImageDataGenerator?

# %%
train_image_gen=ImageDataGenerator(
            
        rescale=1.0/255,
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.3,
        horizontal_flip=True,
        shear_range=0.2

)

# %%
test_gen=ImageDataGenerator(
            rescale=1.0/255 ## no augmentation on testing data

)

# %%
train_gen=train_image_gen.flow_from_directory(
            "images",
            target_size=((224,224)),
            batch_size=128,
            class_mode='categorical'
)
# Out:
# Found 808 images belonging to 4 classes.

# %%
train_gen.class_indices
# Out:
# {'cats': 0, 'dogs': 1, 'horses': 2, 'humans': 3}

# %%
from matplotlib import pyplot as plt

# %%
for (x,y) in train_gen:
    print(x.shape)
    print(y.shape)
    
    for i in range(5):
        plt.imshow(x[i])
        plt.show()
    break
# Out:
# (40, 224, 224, 3)
# (40, 4)
